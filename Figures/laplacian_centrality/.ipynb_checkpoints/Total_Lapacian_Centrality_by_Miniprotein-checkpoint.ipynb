# %%
import os, sys
import random
import pandas as pd
import numpy as np
import networkx as nx
import natsort as ns
import glob
import time
import scipy
import copy
import csv
import matplotlib.pyplot as plt
import seaborn as sns
data_dir = 'path/to/Simulated_Tempering_Logs'

# %% [markdown]
# # Plot Histogram of $\Delta \Sigma$Laplacian Centrality by Miniprotein

# %%
from scipy import stats
beta=0.593**-1
titles = ['A8','A13','A18']
fig,axes = plt.subplots(1,3,figsize=(15,5),dpi=300)
for i,ax in enumerate(axes.flat):
    mp=titles[i]
    if i == 0:
        x=4
    else:
        x=6
    lc= np.loadtxt(f'{mp}_dLC.log',usecols=x)
    en = pd.read_csv(f'{data_dir}/{mp}out100Msteps.traj',delim_whitespace=True)
    en.dlc=lc
    x1=en[en['k']==0]['dlc'].values
    x2=en[en['k']==5]['dlc'].values
    w=np.exp(-beta*en[en['k']==0]['energy'].values)
    p = len(np.where(x2 >= np.average(x1,weights=w))[0])/len(x2)
    sns.histplot(data=en,x=en[en['k']==0]['dlc'],weights=np.exp(-beta*en[en['k']==0]['energy']),
            stat='probability',palette='colorblind',multiple='stack',bins=50,label='Weighted',ax=ax)
    sns.histplot(data=en,x=en[en['k']==5]['dlc'],stat='probability',
             palette='colorblind',multiple='stack',bins=50,label='Null',ax=ax)
    ax.text(-6000-i*100,0.08,f'$\mu$={round(np.average(x1,weights=w),2)}\np-value={round(p,2)}')
    ax.set_title(mp)
    ax.set_xlabel('$\Delta \sum$ LC')
    ax.legend()
    ax.vlines(np.average(x1,weights=w),-0.1,0.1,color='k')
    ax.set_ylim(0,0.1)
fig.tight_layout()
fig.savefig('laplacian_centrality.png',dpi=300)
# Out:
# /tmp/ipykernel_29358/581769320.py:18: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=en,x=en[en['k']==0]['dlc'],weights=np.exp(-beta*en[en['k']==0]['energy']),
# /tmp/ipykernel_29358/581769320.py:20: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=en,x=en[en['k']==5]['dlc'],stat='probability',
# /tmp/ipykernel_29358/581769320.py:18: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=en,x=en[en['k']==0]['dlc'],weights=np.exp(-beta*en[en['k']==0]['energy']),
# /tmp/ipykernel_29358/581769320.py:20: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=en,x=en[en['k']==5]['dlc'],stat='probability',
# /tmp/ipykernel_29358/581769320.py:18: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=en,x=en[en['k']==0]['dlc'],weights=np.exp(-beta*en[en['k']==0]['energy']),
# /tmp/ipykernel_29358/581769320.py:20: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=en,x=en[en['k']==5]['dlc'],stat='probability',
